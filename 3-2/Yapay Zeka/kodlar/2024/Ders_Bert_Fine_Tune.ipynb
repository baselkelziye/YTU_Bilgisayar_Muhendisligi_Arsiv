# %%
import pandas as pd
import numpy as np
import re
import torch
from transformers import BertTokenizer, BertForSequenceClassification
from torch.utils.data import TensorDataset, DataLoader
from transformers import AdamW,get_cosine_with_hard_restarts_schedule_with_warmup
from sklearn.metrics import precision_recall_fscore_support
from sklearn.model_selection import train_test_split
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def get_dataset():
    df = pd.read_csv(r"/content/data.csv")
    text = df['text'].values.tolist()
    label = df['label'].values.tolist()
    return text, label

def CleanTxt(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text)
    text=  re.sub(r'bit.ly/\S+', '', text)
    text=re.sub(r'\s\s+', ' ', text)
    text=re.sub(r'(\A\s+|\s+\Z)', '', text)
    text = re.sub(r'https?:\/\/\S+', '', text)  # web siteleri için
    text = re.sub(r"\b[a-zA-Z]\b", "", text)
    text=re.sub(r'(.)\1+', r'\1\1', text)#Ardışık olarak tekrar eden karakterleri iki kez tekrarlayan karakterlerle değiştirir. Örneğin, "oooo" yerine "oo" yapar.
    text = text.replace('I','ı').lower()
    return text

text, label = get_dataset()

cleaned_text = [CleanTxt(tweet) for tweet in text]

# %%
def get_input_parameters(tokenizer_name,x_train,x_test,y_train,y_test,batch_size):
  tokenizer = BertTokenizer.from_pretrained(tokenizer_name)
  #tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-base-turkish-cased")

  # Metinleri token'lara dönüştürme
  input_ids_train = []
  attention_masks_train = []
  input_ids_test = []
  attention_masks_test = []
  for text in x_train:
      encoded_dict_train = tokenizer.encode_plus(
                          text,
                          add_special_tokens = True,
                          pad_to_max_length = True,
                          max_length=128,
                          return_attention_mask = True,
                          return_tensors = 'pt',
                    )
      input_ids_train.append(encoded_dict_train['input_ids'])
      attention_masks_train.append(encoded_dict_train['attention_mask'])

  for text in x_test:
      encoded_dict_test = tokenizer.encode_plus(
                          text,
                          add_special_tokens = True,
                          pad_to_max_length = True,
                          max_length=128,
                          return_attention_mask = True,
                          return_tensors = 'pt',
                    )
      input_ids_test.append(encoded_dict_test['input_ids'])
      attention_masks_test.append(encoded_dict_test['attention_mask'])

  input_ids_train = torch.cat(input_ids_train, dim=0)
  attention_masks_train = torch.cat(attention_masks_train, dim=0)
  labels_train = torch.tensor(y_train)

  input_ids_test = torch.cat(input_ids_test, dim=0)
  attention_masks_test = torch.cat(attention_masks_test, dim=0)
  labels_test = torch.tensor(y_test)

  dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
  dataset_test = TensorDataset(input_ids_test, attention_masks_test, labels_test)

  train_dataloader = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
  validation_dataloader = DataLoader(dataset_test, batch_size=batch_size, shuffle=False)

  return train_dataloader,validation_dataloader

# %%
def GetModel(model_name,learning_rate,epochs,train_dataloader):
  model = BertForSequenceClassification.from_pretrained(
    model_name,
    num_labels = 2,
    output_attentions = False,
    output_hidden_states = False,
  )
  #BertForSequenceClassification
  # GPU kullanılabilirse
  model.to(device)

  # Optimizer ve scheduler
  optimizer = AdamW(model.parameters(), lr = learning_rate)

  total_steps = len(train_dataloader) * epochs

  scheduler = get_cosine_with_hard_restarts_schedule_with_warmup(optimizer,
                                              num_warmup_steps = 0,
                                              num_cycles=epochs,
                                              num_training_steps = total_steps)
  return model,optimizer,scheduler

# %%
def validate(model, validation_dataloader, device):
    model.eval()
    total_eval_accuracy = 0
    total_eval_loss = 0
    nb_eval_steps = 0
    all_preds = []
    all_labels = []
    misclassified_indices=[]
    for i, batch in enumerate(validation_dataloader):
        # Veri işleme ve modelin performansını ölçme adımı
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)

        with torch.no_grad():
            outputs = model(b_input_ids,
                            token_type_ids=None,
                            attention_mask=b_input_mask,
                            labels=b_labels)
            loss = outputs.loss
            logits = outputs.logits

        total_eval_loss += loss.item()

        preds = torch.argmax(logits, dim=1)
        correct_preds = (preds == b_labels).float().sum().item()
        total_eval_accuracy += correct_preds

        all_preds.extend(preds.cpu().detach().numpy())
        all_labels.extend(b_labels.cpu().detach().numpy())
        misclassified_indices.extend(
            [i * validation_dataloader.batch_size + j for j, (pred, label) in enumerate(zip(preds, b_labels)) if pred != label]
        )

    avg_val_loss = total_eval_loss / len(validation_dataloader)
    avg_val_accuracy = total_eval_accuracy / len(validation_dataloader.dataset)

    precision, recall, f_score, _ = precision_recall_fscore_support(
        all_labels, all_preds, average='binary')

    return avg_val_loss, avg_val_accuracy, precision, recall, f_score,misclassified_indices

# %%
def Train_Bert(model,optimizer,scheduler,train_dataloader,epochs,validation_dataloader):
  for epoch_i in range(0, epochs):

    model.train()

    total_train_loss = 0

    for step, batch in enumerate(train_dataloader):
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)
        model.zero_grad()

        outputs = model(b_input_ids,
                    token_type_ids=None,
                    attention_mask=b_input_mask,
                    labels=b_labels)

        loss = outputs.loss

        total_train_loss += loss.item()

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()

    avg_train_loss = total_train_loss / len(train_dataloader)

    print(f"Epoch {epoch_i + 1} / {epochs} - Average training loss: {avg_train_loss}")
    val_loss, val_accuracy,precision, recall, f_score,misclassified_indices = validate(model, validation_dataloader, device)
    print(f"Validation Loss: {val_loss}, Validation Accuracy: {val_accuracy},Validation f1-score: {f_score}")
  return model,f_score,misclassified_indices

# %%
X_train, X_test, y_train, y_test = train_test_split(cleaned_text, label, test_size=0.2, random_state=42)

# %%
train_dataloader,validation_dataloader=get_input_parameters("ytu-ce-cosmos/turkish-base-bert-uncased",X_train,X_test,y_train,y_test,32)

# %%
model,optimizer,scheduler=GetModel("ytu-ce-cosmos/turkish-base-bert-uncased",2e-5,2,train_dataloader)

# %%
model,f_score,misclassified_indices=Train_Bert(model,optimizer,scheduler,train_dataloader,2,validation_dataloader)
# Out:
# Epoch 1 / 2 - Average training loss: 0.24276778167465105
# Validation Loss: 0.20646962201539076, Validation Accuracy: 0.9234669811320755,Validation f1-score: 0.9157033380958567
# Epoch 2 / 2 - Average training loss: 0.1871942377693178
# Validation Loss: 0.2014674870051303, Validation Accuracy: 0.9264150943396227,Validation f1-score: 0.9200614911606457

# %%
print(len(X_test),len(misclassified_indices))
# Out:
# 8480 624

# %%
for index in misclassified_indices:
  print(X_test[index])
  print(y_test[index])
# Out:
# kızılay sana bundan sonra 1 damla kan da vermem bağış da vermem.yazıklar olsun..
# 1
# koskoca milli takımın teknik dörektörünün ağzından çıkanlara bak! sonra da milli maçlara herkesi bekliyoruz, kenetlenelim birleşelim. siz önce üstünüzdeki formaları çıkarın sonra taraftarları eleştirin.
# 1
# bunun için miydi tüm uğraş yazık verilen oylara yazık
# 1
# yazık biz senden bizi kollamanı beklemiyoruz adil olmanı hakkaniyetli olmanı istiyoruz .
# 1
# anadolu ajansına soda gönderelim hazmedemediği sonucu açıklamıyor galiba #seçim2019
# 1
# fırsatı olan herkes izlemeli şu an belediye meclisi toplantısını. chpliler çok güzel adamlarsınız be! sıfır nefret diliyle hala açıklama yapıyorlar mis gibi. özlediğimiz hareketler bunlar
# 0
# ayarları bozan adam her şey çok güzel olacak
# 0
# farkettiniz mi hakan çalhanoğlunun yokluğu çok belli oldu çünkü iyi oynadık
# 1
# belki arkadaş benim gibi şizofren 😂
# 1
# bana sevgili degilher şeyi beraber yapabilecegim manyak bi insan lazım,
# 1
# bende bunu anlamıyorun adamı bu kadar gözünde büyüten bir bizin taraftar var adam cl liginde galatasaraya 3 tane atınca bile yorumcular adamı sallamıyordu
# 0
# #7temmuzdünyaromantiklergünü 16 yıllık evli bir çift ancak çift'in biri zorbalıkta sınır tanımamış. 16 yıl geçmiş; tutmadığı sözleri, uyguladığı sıradışı şiddeti ile vaatlerde bulunmakta hala. eşine göre ise dünyanın en romantik kişisidir kendileri.
# 1
# benim için sen hiçsin sözlerin çöp
# 1
# hakkaniyet olsaydı gs bugün sizin 9 puan altınızda orta sıra takımı olurdu, ama iktidar üstü güç ne zaman abdurrahim yönetimde olsa yukarı çekiyor. başakşehir 8 puan öndeyken bile besbelliydi bu durum. başakşehir paravan takım, onların misyonu gsnin önünü açmak.
# 1
# bebeğim yaza zayıf giriyorsun ama karakter olarak.
# 1
# katarlı görücü gelir  kıza artıkın kaçıncı eşi olur bilmem .
# 1
# i̇ki tip insan vardır 1. süslenip dışarı çıkan 2.kapısının ününün otunu yolan.
# 0
# onun icinmi tsk yi yok ettiniz.
# 0
# sen burada açılan dövizleri anlayacak kadar akıllı kadın olsan bunları kullanmazdın.. bir kadın olarak.
# 1
# pkkya 20 bin tır silah veren abd müttefik,esad düşman,onunla görüşülemiyor.aklımıza sahip çıkalım..
# 0
# bir ara kendimden bile vazgeçmiştim, ne büyük aptallık.
# 1
# sınavlardan 80-100 arası puan alanlar yerine özel mülakatlarla aldığınız ki puanları 60 ı geçemeyen düşük ıq lü yandaşları işten çıkarıp yüzünü bilime dönmüş gerçek emekçileri işe almaya başlarsanız belki size inanırız!!  yüzden bu tür tweetleriniz hiç inandırıcı değil!!
# 0
# peki sen seçildiğine nereden kanaat..dur bir dakika ben binali konuşuyor sandım.kaç gün oldu ortalarda yok madem kazandı niye kendisi sahip çıkmıyor?ekrem i̇mamoğlu dimdik duruyor karşınızda biraz zorunuza gidiyor tabi rtenin istanbulu kaybetmesinin faturası ağır olacak
# 0
# şimdi düşünün bunlar iktidara geldi aziz milletim gerçekten halinize ogo zaman gerçekten aglayln düşünmesi bile bigi felaket allah bu millete basiret versin
# 1
# 😂😂 sen cansın,  küfürbazı diyorum
# 0
# taymın en büyük goygoycuları şuan bir bir içini döküyor ekibe karşı. gülüşü güzel olanın acısı büyük olurmuş lafı doğruymuş egkgnfvkdxled 8 sayfa yazılar tweet dizileri falan ne yaşattınız lan onlar bile bıktıysa
# 1
# bütün büyükbaş hayvanları böyle seviyorum
# 1
# saygı beklediğin kişiler saygın kişiler olmalı. onlarda saygı yokki sana göstersinler
# 1
# yakasında atatürk rozeti olan bir adamla muhabbet ettim adam benden cesaret aldı bir döküldü bir döküldü resmen atatürk dusmaniymis meğer..dedim rozet ne boşver dedi..
# 0
# gecenin bir vaktinde uyuyan bütün canlıları uyaran yerlerinden eden ve birçoğunun ölümüne neden olan olan bu kutlamaların tamamen yasaklanmasını istiyorum. zaten bu patlayıcıların tamamı ithal bunun için yurt dışına milyonlarca dolar para ödeniyor haramdır haram.
# 1
# böyle yemek ismarlayarak terörün beli bükülür tabi.
# 1
# bende diyorum kim bu köepekçi
# 0
# 669 khk ile sorgusuz sualsiz yaa sen kimsin necisin nasil okudun nasl hayatlamücadele edip bu gunlere geldin atamasına 15 gün kala hakları verilmeyen ve şuanda hiçbir kurumsal işe giremeyen khk ile yaftalanan evladimın hicbir illagal ilişiği iltisağı olmayan velbalini aldılar
# 0
# taraftarın gecesini haftasını rezil edenlere söylenecek çok laf var. kifayetsiz antrenörlerin biran önce değişmesi, laubali ben gevşek futbolcuların da kulağının çekilmesi lazım
# 0
# fenerbahçe nin tek kurtuluş yolu; aziz yıldırım hangi hocaya gittiyse 1 fazlasını vermektir.
# 1
# camı açtım aşağıda sevmediğim kızların odasına pozisyon alarak izliyorum videoyu kusarsam oraya kusayım diye
# 1
# ben direk ağzını yüzünü kırasın geliyor :)
# 1
# i̇yide siz rus kızlarını bide hint kızlarını türk kizlarindan güzel bulurken bişey yok.oysa arkadaş sizin gibi sınırların dışına başka ülkelerden örnek vermemiş.en azından türkiye içi örnek vermiş.hak veriyor aynı şey kızları içinde geçerli doğulu kızları daha güzel kaş göz kiprik
# 0
# ünal hocam bu akbaş senin başını yiyecek yazık etme kendine
# 0
# hay sizin gibi once'ları.. şarkı sızdırmak nedir ya??
# 1
# belki bir oy alabiliriz diye yapamayacakları yoktur
# 1
# gözü açık olduğu her saniye dedikodu yapan baldız, eşimi arayıp kurbanı senin adına keseceksen şükür namazı kılman lazımmış bilmem ney abla öyle dedi diyor. evliya olup çıktılar başımıza.
# 1
# hayvanların içgüdü çok garip yavru küçükken türk ailesi gibi koruyucu kollayıcı yavru büyüyünce güçlenince amerikalı gibi dostum artık başının çaresine bakmalısın diyo yüzüne bakmıyo
# 0
# suriyeriler 3 aşamada suriye geri donderilecekler yeni sehilerde kole diye calistiralacak . sirtini donduler islamda kactilar zilet icinde hayati terci ettiler..
# 0
# bu şiir can baba dan tüzüğü büzük olanlara gelsin.
# 1
# i̇tira yok kardeşim başarıya göre yiyebilir ama bir video var perviz ve atakan birlikte video çekmişlerdi kim alır diye biri soru sordu belli olmaz dedi. ama tabi bana göre de perviz daha iyi bir dövüşçü sanki
# 1
# begüm acar tamamen orjin resım zevk benimle yaşamak ıcın kondom sart degıl kendı yerınde sevısıyor #izmirescort tadına doyumsuz halıyle sızı karsılıyor zevk almak ıcın arayın..09983898909
# 0
# harbiden ıy yani nasıl bir ergenseniz bir kafeye dadandımı dadanıyonuz
# 1
# kürdilihicazkâr etkilemek hazır yiyici dış pazar #uzaktanydscomsayesinde direşmek
# 0
# sana daha fazla tahammül edemem artık. takibi bırakıyorum. allah feraset versin.
# 1
# boştan yere kimseye gönül baglamayin bunun adi aptallik oluyo karsindaki insanin gözünde küçük düşüyosun  kadar başka bisey yok
# 0
# senin tasmanı tutanların korkulu rüyalarından bir mücahid senin ne olduğun bile belli değil
# 1
# allah belamı versi̇n as long as you love me çok güzel ağlıcam şi̇mdi̇
# 0
# hergün aynı şeyi yapıp farklı sonuç beklemek aptalıktır.. oy verip bu sefer olacak diyenlere gelsin..
# 1
# #hastaolmadanreçeteyazmaksuç listede ama #yusufdede listede değil. kendinizi haklı çıkarmakta hep mahirsiniz zaten! vicdan yahu azıcık vicdan!
# 1
# ayrıca,seninle ve aklınla kurtun ne işi var;olsa olsa ben düşerim😉😚
# 0
# sen sorunu söylerken bile, kürt ve türk'ü ayrıştırıyorsun.. biz kardeşiz dedikçe sizin gibiler kaşımaya devam edecektir. çünkü, pkk ile bir ve berabersiniz..
# 0
# daha demin bir cümle kurfum : çocuğun poposuyla çıkmak istiyorum diye . kslskdkxoskw linç atmayın çok güzel çünkü
# 0
# şimdi mantıklı düşünelim, bangtan' daesang vermeyen törenin prestijinden şüphe edilir bu yıl. soribada gibi bir yalaka bu sene napacak bakalım. hak edene mi gidecek yoksa bu yıl cb bile yapmamış sadece oylamayı önde bitiren gruba mı gidecek, göreceğiz.
# 0
#  değil de ne yazip sildin onu göremedim. baya giydirmis size
# 1
# benim dm mi kapalı valla nasıl açıldığını bilmiyorum öylesine giriyorum twitter
# 1
# arkadaşlar hesabımı engelledi̇ler bu yeni̇ hesapta devam edeceği̇m durmak yok yola devam.. fetoşcu hekırlara di̇kkat edi̇n bi̇zden gözüküp hesabımızı hekli̇yorlar ben kurtaramadım..
# 0
# öyle ölmem bozuk  kromozomu füze at jdkdkdkkd
# 1
#  400 lerden daha önemli olan ülke yönetimidir. farzı misal ülkenin yönetimi chp ve çetesinin eline geçerse bırakın  400  500,  600 dahi olsa bu silahları kullanılamaz mührü basılır. dünya'da ülkesine düşman bir parti var  da chp'dir..
# 1
# boyd visca gibi sistem oyuncusu şu an sistem mi var da bu yorumu yapıyorsunuz ve bu boş yorum için para alıyorsunuz
# 1
# senin arap tanrılarına tapmaktansa deist olmayı tercih ederim 😊. eminim kadın profili kullanan fake kişisindir. çünkü malum senin gibiler anında ceza aldığı için yoksa bu cesaret nereden gelecek
# 0
# zaten canan la ekrem de chp li değil aslında. aslında chp ye de dediğim dedik çaldığım düdük bir reis lazım. 50 yaşımdayım ilk defa chp ye oy verdim. şimdi de partiye üye olmayı düşünüyorum
# 0
# .koç ,.orman ve .gümüşdağ’ın yönettiği tff’nin pfdk’sından hocamız “fatih terim’ yine uyduruk cezalar verilmesin diye tepki amaçlı gündem tt çalışması yapılsın mı ?
# 1
# yav elbette vardır isteyerek giden cins tipler. ama ajan da az değildir
# 1
# tucecim laf sokun sokmayın demiyoruz ama önce kendinize girmediğinden emin mi olsanız acaba 🤗
# 1
# anlamazlar. tarikatlar devam. hiç eksilmeden çoğalıyor.
# 1
# bu türler niye bizim(alevilerin) adina konusuyor?
# 1
# heci abe,çokta takıntı yapma,adalet çoktan beri yerlerde. senlik bir olay değil.
# 1
# bir de keyfi olarak burs ve kredilerimizi kestiğiniz için sürekli olarak para sıkıntısı çekmekten de
# 1
# mutsuzum fakat neden mutsuz olduguma daire en kucuk fikrim yok. surekli aglayip uyusam belki gecer. ınsan olmak, insan kalabilmek ve insan mahiyetinde ki canlilarla ugrasmak cok yordu beni.
# 1
# bu kız starbuckstan beyaz ne içiyor böyle
# 1
# bizans diye bi yer yoktur. yunanla ilgisi yoktur. "doğu roma i̇mparatorluğu" vardır. ayasofya'yı geçin; kırmızı kilise ve patrikhane 566 yıl önce olduğu gibi "cami"ye çevrilmelidir. i̇brahim kalın'ın fatih camii vurgusu yerindedir. caminin yerinde eskiden patrikhane vardı :)
# 0
# tahmini ne zaman kendimizde bi özelliğimizi değiştirebilmemiz için gökten sihirli değnekler yağar çünkü ben bu salak hassaslığımdan kurtulabilmek için  günü bekliyorum 1 gün olacak inanıyorum
# 1
# bizim taraftar bile takmıyor artık. son iki sezondur kendi taraftarına gider yapan adamın samimiyetine, açıklamalarına kim inanır ?
# 0
# abd-trump ilk defa bu kadar açık tehtid etti türkiye'yi. şaka değil ekonomik olarak mahvederiz dedi. rahip brunson olayında dolari 4 liradan 7 liraya çıkardığını düşünürsek mevcut şartlarda cidden sonuçları çok vahim olabilir.
# 0
# sence ergenliğini ispatladı mı? zeki bir adamsın ama yandaşlık ağır basıyor haliyle.
# 1
# ana sayfam kudurmuş durumda ama ben asla anlamıyorum ne oldugunu
# 0
# hayır şevki bey. size katılmıyorum. imamoğlu daha 19 gün başkan olmasına rağmen sabuk subuk icraatları ve icraattan çok şovlarıyla insanların tepkisini çekti bile. yaptıkları yapacaklarının berbat teminatı olduğu için bu halk kesinlikle onu seçmeyecektir. halk hatasını anladı.
# 1
# benim hissem var lan. aynı soruyu ben de soruyorum.
# 1
# "hayal kurmayı bırakın yaw" gibi bi çomar cümlesi kurmayacam. hayal kurmayan insan yoktur, olamaz. bilinç açık olduğu sürece hayal kurulur.  hayale insan kendini fazla kaptırmamalı ve yukarda dediğim gibi onun "hayal" olduğunu kesinlikle aklında bulundurmalı.
# 0
# . skubic’in futbol ukalalığı puan kaybettirmeye devam ediyor. 😡
# 0
# öptüğünü düşünüyorum dudak yerine parayı para için açar mı sevişenler arayı madem para mühimdi al koluna parayı çantana da koy aldığın  kocayı..😉#şiirsokakta
# 0
# elitlerin arasında pedofili tek başına bir sapkınlıktan çok bir statü gösterisine dönüşmüş durunda. toplumdan üstün bir kast olduklarının ritüeli gibi..
# 1
# sn..akşener'in kuruluşunda,bilgim,birirkimimle yardımcı olmak için yer almak istedim.hatta torpil yapmaya,yaptırmaya çalıştım:baktım ki kabul görmüyorum.ulan secdeden başka eği̇li̇rsem,allah'ın, peygamber'i̇n lanetleri üzerime olsun.bu ne omurgasızlık,bu ne karaktersizlik yahu!
# 0
# sarıgülü gönderdi̇, ekmeleddi̇ni̇ gönderdi̇ gel muharremi̇ gönderdi̇ sıra ekruma geldi̇ ama uykularına gi̇ri̇yor herhalde :)
# 1
# trt’ye verdigim vergi haram olsun ne demek kovboy filmi yok bu gün #pazar
# 1
# ya twitter da şu takip/takipçi olayını çok gözünüzde büyütüyorsunuz sadece eğlence mekanı ve bolca geri zekalı kitlesi genelinde hakim bu mecraya- ölü yatırım yani twitter
# 0
# #uzmcvslarbakansoyluyla sayi̇n bakani̇m si̇z 15 temmuz da trt i̇ken jandarma genel muduru nerde i̇di̇..
# 1
#  arkadaşlarınınım mükemmel ingilizcesi vardır. 3 aylık bir dış ticaret kurşuna gitsinler. akreditif.. vesaik. gümrük. swift uygulamasını yalar yutarlar. 4. ayda binlerce dolar maaş alırlar..
# 0
# ti̇yatrocu ti̇yatrocu ti̇yatrocu şenol güneş
# 1
# sosyal medyada foto paylaşılır, video paylaşılır, müzik paylaşılır ama yemek paylaşılmaz bunu ne zaman öğreneceksiniz acaba yerinize utanmaktan bıktık yahu!
# 1
# abicim referandum gecesini berbat sunmuştu halk tv. berbat bir iç karartan sunuş ve ekran konuşmalar sıkıcı. tek sizi izliyorduk halk tv de eminim dah  iyi kanal da devam edeceksiniz
# 1
# yarın vesikalık çektirmeye gidicem şimdi bu sıcakta nasıl makyaj yapıcam nasıl saçıma 230 derece ısıda maşa yapıcam hadi onu geçtim nasıl evden çıkıcam ?? yaz ayı nefretimsin
# 1
# kızlar kufur edince cok garip bisey ortaya cıkıyo😊
# 1
# koç ailesinin kökeninin ne olduğunu daha önce dile getirmiştik..fenevliler neye seviniyor,hani 3 temmuzda aziz başkanı yedirmezdiniz ne oldu?!
# 1
# tahminen ne zaman bir masada otururken sana karşı içimde daha önce kimseye oluşmamış kin ve nefreti anlatabilirim
# 1
# hakemler tarih yazıyorlar / 9 kişiye karşı 3-2 önde olacak alanyasporu kaybettirdi
# 1
# çocuk "gayimsi" hareketler yapmıyor. göbek atiyor diye gay ilan edilir mi küçücük çocuk ya?
# 0
# siz hiç türk islamcı hocaların akp eliyle kurulan şans oyunlarının hükmüne dair açıklama yaptıklarını duydunuzmu? ama hdp milletvekili garo yaptı en son. peki devletin i̇sraille ticari ve diplomatik ilişkiler yapmanın hükmüne dair? ama zavallı halka gelince cola ve dolar haram.
# 0
# kadın dediğinin 1 tek erkegi olmalı
# 1
# hesaplarin parodi olmasi mesele değil bu adam komunist atatürk'ün nefret ettiği ideoloji fox tv hem atatürk'çü olup hemde bu adama günde bir saatini ayiriyor burada bir çelişki var canli yayinida bari atatürk'ün bomba attigi dersimden yapsalardi.
# 1
# asfer siz bir bataklıksınız sizden katiyen vazgeçemiyorum, size mütemadiyen her an düşeceğim çünkü ruh hastası olmak bunu gerektirir.
# 0
# semihi elerkende torpille eledi sen kabul etmeyebilirsin ama damlanın torpili 2016 dan kalma ve hala devam ediyor panoramalarda 0 eleştiri öbürleri ühü diyor panoda linç ediliyor ama damla sanki sadrazamın kızı sanki melek bu torpil değil de nedir birsen bile eleştirildi ya
# 1
# tc güney ‘de kendini sağlama almiş?cahş ailesi onun bütün isteklerini yerine getiriyor kuzeyindeki kürt’ler istediği kadar savaşsın??
# 0
# çalmışlar demeden efendi gibi tekrar bazı yerlerde sayım isteseler neyse.. ıtiraz etmeseler ıstanbul da oylarımıza sahip çıkmadınız der seçmeni fakat bunların amacı bir boşluk yakalayıp sonuçları değiştirecek hamleler yapmak.
# 1
# özgür medya kimmiş hangisiymis bi soyleseydi keşke. ay iyi ki izlememisim. saldırı ve paniğe bak bunlar nasil univ de hoca olmuş acaba 🤷‍♀️ ne öğretiyor öğrencilerine?
# 1
# ya artık kanun çıksın bu hayvanlar için içim dayanmıyor yanarak ölün insallah
# 1
# halinin olmadığını anladığı için bu yöntemlere başvuruyor çakma parator artık herkes farkında medya hariç onları da takan yok
# 0
# i̇çin rahat olmasın yazık ettin bize.
# 1
# her tweetin başına niye cesareti olan yazıyosunuz biz yorum yapmayınca korkak mi oluyoruz
# 0
# i̇yi̇ parti’ye geçsene  halde, madem cumhur ittifakı çatırdıyor. i̇lkeler görüşler farklı, hala akpye ne diye stepnelik yapıyorsunuz?
# 0
# ne bileyim sen hastayım deyince bende veteriner okumaya karar verdim
# 1
# ha eğer derseniz ki ‘benim tartışma kültürüm bu kardeşim, bilmeden fikrim olan konularda dayanaksız argümanlar üretirim’..  ayrı. öğrenmek istiyorsanız anlatalım, cehaletinizle çevrenizi enfeke etmek istiyorsanız uzak duralım sizden. seçim sizin.
# 1
# söz de açılım süreci adı altında yapılan mitingte neden şanlı türk bayragimizin yasaklandigini ve kürt vatandaşlarımızın arasına pkk miltanlari sizdirlarak neden pkk sembolu sulgan ve pkk bezi sallandirilgini.sınırda çadır kurup pkk elebaşlarinin iktidar tarafından af edildigini
# 0
# #2828shçekmağdurediliyor hakkımızı i̇stiyoruz sadece! yetim hakkı yemek kolay değildir.
# 1
# gördüm de senin gibisini görmedim feyzioğlu
# 0
# -düşünce özgürlüğü adı altında tamamen alakası olmayan bir yerde ve alakası olmayan kişilere karşı kafasına ilk gelen yorumu bir an olsun düşünmeden yapan insanların yorumunu görmeme ameliyatı-kansere çare cerrahpaşadan..
# 1
# ya geri gönderin yada kamp alanına da toplayın alın bunları! bu gidişat felaket getirir allah aşkına yetkililer görsün artık yeter #ikitelli
# 1
# piyano çalamadığım için vatan haini ilan ediliyodum mk
# 1
# 2,5 milyar $ -400 rusların açtığı kredi̇ ile alıyosun daha parasını bile ödemedin,adamlar satacakları malın parasını verdiler bu 1 ecevit orada burada para aradı ama abd, ab ve dünyaya kafa tutarak toprak aldı toprak bugün  topraklar üzerinde kktc var ve bugün 45.yılı bu da 2
# 0
# şu adama bunca zaman ekmek veren,prim veren kim varsa allah katında asla affedilmesin inşallah 🙏🙏
# 1
# adsl’ karışmayalım ama mobil interneti skiyoruz. biliyorsun tercihli insanlarız
# 1
# sen konuşuyor musun hala 😄 seni akkoyunlu terör işbirlikçilerinin yanında olman gerekiyordu 😄
# 0
# bnelmle yuruyuse ciksan yuruyusten sonra iskender yerdik ama senin kaybin
# 0
# dökül.
# 1
# şaka bir yana artık gerçekten yaşanacak yer olmaktan çıktı burası bu ne lan dalga mı geçiyorlar bizle
# 1
# gsporto hilbettvde boş kafayla dolu yazamazsın !
# 1
# parayla saadet olur, merve olur, hale olur, jale olur. parasız en fazla naciye ne biliyim hayriye falan olur..
# 1
# bana yaşattığın hiçbir acıyı, sancıyı unutmadım 10 değil 30 yıl geçse de unutmam, her gece yatmadan önce dualarımdasin artık ama yasattigin her seyin 10 katını sürünerek yaşaman icin
# 1
# hı hı evet i̇nek değilsiniz siz. sadece 15 tatilde 15 soru bankası bitirmek gibi küçük hedefleri olan sıradan öğrencilersiniz.😒😒
# 0
# elif nasıl ki ben erkek halimle zina'ya yaklaşmıyorsam  zaman kadınlar da yaklaşmasın.sana soruyorum şimdiki kadınlar demiyormu bu vucut benim kimse karışamaz.bu söylenecek lafmı.bunu anla ve hic merak etme erkekler kadınlardan daha cok dikkat ediyor.
# 1
# mahallemde sokak hayvanı olamaz ama sokak hayvanlarını seviyorum ya onları koruyalım bu arada yeni mama çıkarttık satın almak ister misin
# 1
# tamam anladık kardeşim çok anarşiksin sigara içilmez yazısının önünde sigara içiyosun helal be
# 1
# komik olsa gulerdim dimi tassam ama bak kusuyorum
# 1
# bu görevi yerine getirebilmek icin kimbilir kaç kişiden adalet çaldılar..işçi ölümleri bekliyor, iddianmesi olmadan içeride yatan insanlar, kadına şiddet davaları, çocuğa cinsel taciz davaları-“şiddet içermeyen eylem tanımı” ile suç bile uydurdular-cumhuri̇yetçi miyiz, kralcı mı?
# 1
# biraz düşünün bence, sonra size bunları fena yedirirler..
# 1
# dinar turizmin saygıdeğer şöförü can bey bize yabancı müzik eşliğinde rally deneyimi yaşattığınız için çok teşekkür ediyoruz.
# 1
# artık şu hastalığım geçsin ya da öleyim amk
# 0
# af çıkmasını istemeyenler sizde  tadi alın ins ozaman anlarsınız bizleri
# 1
# seni beyazlar içinde görmeyi çok isterim mesela kefenle
# 1
# olmasın kaygı hayat hep boktan ve aynı
# 1
# bunun dedigi maclarin tersine 100er tl atsaydim simdiye kasamda 100 tl olduydu amk :
# 0
# bazı insanlar bi ona bi buna sallamaktan aynaya bakmaya vakit bulamadılar galiba
# 1
# 12 senedir veliyim, bugüne kadar devletin dağıttığı kitap yeterli diyen bir öğretmene rastlamadım. senelerdir her dersten destek kitap alıyoruz. bu kitapları kim hazırlıyor, neye göre hazırlıyor, gerçekten yazık. kağıt israfı.
# 1
# profile i̇letişim uzmanı yazmış bide inanılır gibi değil!! bence senin uzmanlık alanın daha farklı alanlarda olmalı insanları çekememek gibi i̇nsanların eğlenceleri seni neden rahatsız etsin ki teyze ?
# 1
# ben anan gibi herkese telefon vermem koçum !
# 1
# valla biz aç kaldıysak da kendi aramızda aç kaldık gidip amerikayı ağzımıza almaya çalışmadık en azından
# 1
# yine iyi niyetimizden kaybettik bundan sonra geberseniz de size karşı iyi olmıcam
# 0
# kızlığın soyadından önce bozuluyorsa , ölmelisin güzelim . . !
# 1
# dünkü dönen dolaplarda sizin de parmağınız var, aa ya atamanız hayırlı olsun, ne kadar mutluydunuz akşam,
# 1
# elinize sağlık soğana bile húkmedemeyen bir ülke yönetimine sahibiz.
# 1
# bugün sılho'nun 6-8 ekim açıklaması hükümet ile pkk arasında alicengiz oyununu biraz da olsa ortaya çıkarıyor gibi ama görebilen gözlere!
# 1
# güzel kardeşim şapur şupur öpüyon amaciniz varsa gidin çözünde biz bari izlemeyek
# 1
# yuh başka hangi elisa var
# 0
# #kentmeydanı #bursatravesti #bursatravestileri #bursasex #bursagay #bursamasaj #bursaescort #bursapasif isteyene nefes isteyene heves olurum ☎️0375 106 08 73☎️yalarım yutarım dik tutarım💋❤#bursapasif sorunsuz beraberlik 👄
# 1
# bu adam 16 yıldır iktidarda. pkk'ya daldı. fethullah cemaatine daldı. amerikaya kafa tuttu/tutuyor. suriye'de silahlı operasyonlar bile yaptı. hala dünyanın dört bir yanında devam ediyor operasyonlar. yani sen söylenene değil, icraata bak, siyaset bu. bir nevi savaş.
# 0
# staj dosyamı son güne bırakan aklıma tüküreyim hastanede ne yaptığımı hatırlamıyorum ne yazacam şimdi ben bu dosyaya 🤦🤦
# 1
# bize zaten yapmayan yok tarihte hainlik
# 0
# fatih hoca en az 2 forvet lazım diyor baskan olursa olur olmazsa eren yeter diyor sen hala başımızda fatih terim var diosun sakamisin
# 1
# marcaonun kırmızı kartında ki suç ilk önce orta sahayı bu kadar güçsüz bırakan teknik heyettedir. ölmeye 3 günü kalmış selçukla deplasmanda oynarsan lige yeni çıkmış denizli çakar affetmez
# 1
# bunların alayı yok olsa hiç bir derdimiz olmaz ..
# 1
# birlik beraberlik adı altında her yaptıklarını koşulsuz kabul edip desteklediğiniz bazı grupların "abi"leri kızmasın sonra; aman dikkat!😏
# 1
# fanboy ve fangirller bu dünyanın veremidir
# 1
#  da bilmiyor kim olduğunu verilen sufle günü belirliyor..
# 1
# avm çocuğu seni sabah sabah gene birazdan starbucks 😀
# 0
# gelin tarafı gelmiş mi stadyuma, gelinimiz fenerbahçe hazır mı akşama gerdek için kocası galatasaray onu bekliyor 😉😂
# 1
# biz bırakmayız 15 temmuz planlayıcısı diye suçladık pkk fetö dedik abd ye posta koyduk ve bıraktık madara olmaz mı insan
# 0
# şimdi, seni senle baş başa bırakıyorum. kalbin kırık,uykuların kaçık ve hiç mutlu olamaman dileğiyle elveda..
# 1
# sokakta bir deney yapılıyor savaştan kaçmış evsiz birine kapınızı açar mısınız diye herkeste tabi ki diyor suriyeli bir adamı karşılarına diktiklerinde ordan uzaklaşıyorlar aynı deney suriyeli bir kızla yapılıyor herkes de açıyor evini kim bilir hangi iğrenç düşünceyle.
# 0
# tekfirci, cihatçı bir çok islamı tarikat, mezhep vs bırakın saygıyı bizzatihi farklı olanın canını, malını, ırzını hiçe sayıyor ve el koyabiliyor. bu mudur saygı? ne yazık ki bu yaklaşım müslümanlar arasında epey yaygın. i̇şi̇d, kaide vs vs benzeri bir sürü yapı güncel örnekler.
# 1
# arabalar başıbozukluğuna aramamış bereketliydi efsaneleşmekte zorlamadığınızı duyurulmamasını #kadınkatilipkk sövdürtmem
# 1
# okan koç ne patatesi soydun orada yorum yapıyosan eleştiriyede açık olacaksın milletin aklıyla alay etmiyecen
# 0
# hepsi geçer ekonomik sıkıntı geçer küskünlükler kırgınlıklar geçer her şey geçer de rüzgara göre yön alanlar geçmez.
# 1
# bazen hangi yüzüne konuştuğumu bende bilmiyorum
# 1
# küçük emrah bunun kadar aglamadi
# 1
#  senin dediğin 4 otobüs dolusu suriye liydi yani yarısı suriyeliydi kardeş medya da gördüğün her şeye de inanma. bu da benden sana tavsiye.
# 0
# bunlar su katılmamış oç vara gidilen pozisyona bak
# 1
# yine grup oyunu hey allahım ulan yapın parkur atakan parçalasın dedik. ama helal olsun adam fragmanda yıktı parkuru
# 1
# #thk neden japonya olamadık di̇ye sorma, thk'ye bak !.. 1952’de türkiye’de motor fabrikası kapatıldı. dünyada uçak üretimini ilk yapan ülkeler arasındayken, uçak fabrikalarımızı da aynı zihniyet kapattı; gdp’ler; genetiği değiştirilmiş politikacılar.
# 1
# senin söylediğin akp nin 16 yıldır yaptığı mağdurum mağdur edebiyatının algı operasyonudur. yahu 16 yıldır tek başına iktidarsın, senin de kabul ettiğin gibi ekonomi sıkıntı içinde,son 4 yıldır her şeye erdoğan hakim,akp nin hiç mi hatası yok? devleti dış güçler mi yönetiyor? 🤔
# 0
# hayır  hayvan gibi yediğini sanmak
# 0
# selam ara bosalalim 3g cam var gizli no açık yaş farketmez doyumsuzum yatakta çplağm 08020128275
# 1
# ne yazık ki günümüzde "bizden" olana ses çılarmıyorken "ötekilere" demediğini bırakmıyor.. ama siyasal i̇slamcılar açık ara önde bu işte..
# 1
# adamın adı yeliz mi ? puhahaha
# 1
# sinüzit kadar şerefsiz bişey yok birazdan beynim kulaklarımdan akacak
# 0
# merve kavakçı meşhur muhalif vekil cihangir i̇slam'ın karısı degilmi. neler oluyor, kim kiminle, kimler hangi projenin elemanı. allah'ım bu nasıl ülke
# 0
# bi tüküreyim dedim çeneme yapıştı
# 0
# kendi selameti icin hürriyetten vazgecmek isteyenler ne selameti
# 1
# kuran kurslarında erkek çocuklarına meyleden müminler, gene "en ahlaklı biziz" oyunu oynuyorlar.
# 1
# tüy kadar nikos' zor yendi artistlik yapıyor. her şeyi rezil 😂 #survivor2019
# 0
# alişan, hülya koçyiğit; sanatçı olmasa bile türkiyeyi temsil eden önemli spor insanları arda turan, hakan şükür, kenan sofoğlu ve daha bir sürü örnek. hiç değilse bile ”size yandaş” sanatçıların yaptıkları dalkavukluk olmuyor mu? komik. eleştiriyi kabul etmek bu kadar zor olmasın
# 1
# zor olmuyor mu her defasında engel yemene rağmen fake hesap açıp durmak tek kelimeyle işsizsin
# 1
# biz mustafa kemal'in askerleri olmaya devam edeceğiz, bazıları şenolun yaveri olsun varsın. #zıplamaşenoldikişlerinaçılır
# 1
# ya ne diyosun allah aşkına ne demeye çalışıyosun. ne yapmak maksadın ?
# 0
# bu konuyu hiç bilmiyorrum ama öyle bişey varsa eğer mila kerim'in kızıysa ve merve bunu evli iken yaptıysa oyaya metres diyenler merve'de .. demesi lazım #ufaktefekcinayetler
# 1
# bütün abazaları rezil etmiş.helal olsun kadınaa bence..
# 0
# ben hatylıyım ve sanıyorum sizin mültecilerle ilgili bilginiz yok pavyonlara sermaye olan kaplarda tecavüze uğrayan, sokaklarda sefil bir hayat süren, tecavüzcüden kaçan, denizlerde boğulan insanları görmek yerine mazlum insanlar arasında bulunan bir kaç serseriye odaklanmışsınız
# 0
# sen kendi kendini aklamaya çalışıyorsun birak seni halk aklamaya çalışsın,seçilmiş başkan olarak hala neden belediye başkanlığından el çektirildiğini açıklamadın
# 0
# muhtar olduğunu bilmiyordum çek vur beni
# 0
# ortak noktaya bak, havaalanında bekletilmek:dd bir de ekrem imamson binali gibi devletin kılıcını çekip saplayamiyor kimseye.
# 1
# senin düşünmemen çok normal  yüzden bok atabilirsin :)
# 0
# parti içi demokrasi̇ diyorlar ona. bilmemeniz çok normal.
# 1
# galatasaray formasının ağırlını taşıyamazsın giymeseydin keşke
# 1
# eğer maç 0-1 olsaydı son dk penaltıyı verirdi çünkü berabere bitirmesi için talimat aldı her şey planlı var mar hikaye
# 1
# hocam ama siz 15 yaşındasınız diyen bir sınıfa ben nasıl otorite kurucam ? abv küçük göstermek!!
# 1
# kızlar salak salak şeylere allahım nasip et diyip çarpılmak mı istiyorsunuz kendinize gelin.
# 0
# bir adayı en zayıf yerinden değil, en güçlü yerinden vuracaksın taktiği bu. adam çocuk hakları konusunda çok mu etkin? çocuk tacizcisi dedikodusu çıkarırdı mesela. biden zayıf bir aday. koyunun olmadığı yerde abdurrahman çelebi bu sene. ama babalığı belki en güçlü yanı. 2
# 1
# #1eyluldunyabarisgunu biz türkiye'yiz savaşçı milletiz düşmanlara karşı vatanımızı savunuyoruz sizlerin amacı bellidir
# 1
# sahip çıkıyor işte devlet, baktı chp yapamıyo el attı, sanada atsın istersen
# 1
# bu maç çok rahat geçer saplarız . andonenin 2 golü var
# 1
# bir insanın yavşak olduğunu anlayınca azcık bi umudum varsa  da bi anda içim de ölüyor yerini tiksinmeyle karışık nefrete bırakıyor.
# 0
# bu ne yaa bu nasıl çocuk lan bakamadım sonuna dek korkunç bişey bu
# 1
# geziciler “nükleer enerji’ye de karşıymış.” türkiye’nin yararına olan her şeye karşılar..
# 1
# sabit bir şey varsa  tekamülün müntehası olan mutesavver kemalden ibarettir. muhiddin arabi bu mutesavver kemale ‘’aynı sabite’’ amını veriyor. bu kelime mefküre ‘’ideal’’ tabirinin muadilidir. ziya gökalp / makaleler ıı /
# 1
# hahahahah türk futbol tarihinin en kötu başkanı olarak tarihe geçicek .
# 0
# bekleme kardesim çünkü bunların gerçekten gündeminde öyle bişey yok.. nedeni 1-kapali cezaevi kantinleri para basıyor 2-acik cezaevleri bedava işçiyle dolu 3-yeni millet parkı projesi eleman lazım elaman açık cezaevi mahkumu 4-bedellide kişi başı 20bin tl alacaklar af bedava
# 1
# ah bu fetöcular senin yerine sana benzer biri getirip konuşturdular
# 0
# seni kimse anlamayacak tek başına kalcan.
# 1
# atakanın fan kitlesi emin ol en yüksek yaş kitlesidir twitter da boş yapma bak ınstagram
# 1
# durmadan bir görev veriyorlar size. hiçbir icraatınızı da duymadım. kadın erkek fırsat eşitliği komisyonu başkanıydınız. büyük bir adaletsizlik olan ömürboyu nafakaya karşı bir açıklamanız bile olmadı. bakanken de reisin talimatıyla ne kadar okumuş okumamış adam var işe aldınız.
# 1
# burak bu, ne zaman lazımsa  zaman yoktur
# 1
# halk  ezilenlere namusuyla hayatı yenmeye çalışanlara yerel zulüm i̇ktidar ve muhalefetin asli götevi dir bu ülkede
# 0
# bulmuyor abi işte! diktatörlük uyguladığını söyleyenlere zamanında inanmamıştım ama resmen şimdi göstere göstere yapılıyor. en çok anlam veremediğim konuda zamanında fetö ile adı anılan kulüplere operasyon düzenleteceğine yardım yapıyor bu nasıl çelişki 🤦🏻‍♂️🤔#herseyguzelolacak
# 1
# elbette gelecek esedi var sırada
# 0
# kandil bu toprakların çıbanbaşıdır. ve kısmet olursa kandil harekâtının başında,afrin operasyonunu başarılı bir şekilde yöneten i̇smail metin temel paşa olacak. .i̇nce’nin “i̇lk işim onun apoletlerini sökeceğim” dediği paşa. allah bu ülkeye feraset sahibi liderler nasip etsin.
# 1
# i̇lk okuldan lise sona kadar gezi koluydum  zamanlardan yazılmış kaderim sürtük olacağım belliymiş şxmzşmxlc
# 0
# bir kızın sevgisini nefrete dönuşturecek kadar ökuz olmayın yeter
# 1
# bugün .bakır barosu açıklama yapacak. gelmiyoruz çünkü..diye bir açıklama bekliyoruz>>
# 1
# bayılıyorum kimin ne bok olduğunu bilip salağa yatmaya
# 0
# kardeş kardeş dedikten sonra aşkım sevgilim böceģim demek akwbswocmskwsmekcejwx nasıl bi varoşluk anlatsana
# 1
# evet açtım lütfen takip etmeyin beni kalabalık sevmiyorum
# 1
# “herkesi mutlu edemezsin çünkü pizza değilsin.” kaliteli edebiyat, işte milletçe beklediğimiz atılımlar bunlar. mizahsa da kaliteli mizah işte hocam(!)
# 1
# toplu biberon satışı yapsın gsstore’ler. hediye edelim hamsi ve diğerlerine:)
# 1
# değer olarak ardayı kılavuz alıyorsan bi pusulana baktır
# 1
# birisinden hoşlanmaya başlayınca kadıköy deplasmanı öncesi galatasaraylı gibi oluyoruz. aynı gereksiz umut, aynı geçmişten ders alamama.
# 1
# adam ,uyusturucu ticare yapan insanlarla cok iyi anlisiyor ve onlari cok iyi anliyor
# 1
# yahu ne yazdım bi önceki twitte masa başından sallamakla olmaz içindeyiz işin ve yazıyoruz çıkarın kafaları kumdan gerçekleri görün
# 0
# neler oluyo bu damatın fiyasko açıklaması mı seçim belirsizliği mi
# 1
# kendisin de şeref olsa bütün emeklilere bu şekilde seslenir mi? hala gaspedilen haklarımız varken bu ikramiyenin lütuf diye sunulması bile densizlik..
# 1
# askere gitmeden sakalları son kez salıyım dedim lanet gelsin öyle dediğim güne. yazın sakal bırakmak işkenceden başka hiçbirşey değil. yarın ilk vakiy  sakallar kesile, bian da 10 yaş gençleşilee.. 🤛
# 0
# tabi canım sen kaybettiğim halde istanbulun heryerine kazandık afişleri asarsan .. adam gider anıtkabirde başkan imzası atar
# 1
# ot gibi yaşayıp istekleri olursa allah gördü, olmazsa vardır bi bildiği diyen bi insanı ciddiye bile alamıyorum
# 1
# gerçekten başlıcam dersinede ödevinede finalinede
# 1
# demekki taze daha iyi eskisinden alacanı almış sıra yenisinde onuda beceriri sonra üçüncüye gelir 😜😝😛
# 0
# nasıl bitsinler ki? fetö'şçular suyun süngere nüfuz ettiği gibi devletimize nüfuz etmişler. ne kadar sıkı sıksan illâ arta kalır!
# 0
# lan ne diye yayını kesip erdoğanı veriyorsunuz? survivor  izliyoduk
# 1
# ne olacak şimdi türkiye ekonomisi mı düzelecek? siyaset mı normale dönecek? hiç bir suçu olmayan bu anneyi yavrusundan ayırıp ,suçsuz yere içeri atmak vicdansızlıktır.
# 0
# boş yapıyor işte gündem oldu amacına ulaştı
# 1
# evine dön ve ağlamaya devam et
# 1
# oğlum sen eser west misin tribe girmiş aqqwdheggjıhjüğıjthgjtıbgykfhujbndjbfhbgg
# 0
# hocam, hocam beyin düzülür mü
# 1
# bugün kafama sulukla vuran arkadaşımın omzuna vurdum ve ağlayarak sınıftan çıktı allahım nasıl bir hayat içindeyim
# 0
# “bu kadar anlaşılır izahtan anlamayana ne denilir artık.” diyordunz, şimdi “he he” mi oldu? lütfen konuşmayn böyle beni umrsamadığınızı düşüneceğim.🙂 ben sadece kendinizden bu kadar emin konuşunca belki fikirlerim değişir dedm. ama, tüh yine boş çıktı.
# 1
# ama normal değil mi onlara göre ataları bir put, obje büst falan.. görsel olarak göstermelerini çok yadırgamamak gerek.. zihniyet meselesi.
# 1
# kargalar hepçil ve açgözlüdür. önlerine gelen her şeyi yemek isterler ve yiyebilirler de. ve bu tam anlamıyla karasuno voleybol kulübünün tanımı. haikyū ya baktığınızda besin piramidi gibi, birbirleriyle savaşan takımları birer hayvan temsil ediyor, dateko ve aoba johsai hariç..
# 1
# memelerin büyük süper çok hoşuma gidiyor büyük memeler
# 0
# bence ara sıra aynaya bak.:))
# 1
# seni tanıdığım ilk anda kalbim tekledi yüksek i̇q den yanında sustuğum tek kişisin
# 0
# sizler devletin parasıyla seçim çalışması yaparken iyi oluyor değilmi
# 1
# helal sex shop açılmış işte istediğimiz gerçek islam bu!
# 1
# zincire vurduğum küfürlerin kilidiyle oynuyorsun. yapma !
# 0
# sinirliyim kırgınım bunu sana nah yansıtırım çünkü ben bir malım
# 1
# bu tweette anlatıyor ki̇ atatürk i̇talyanın arasına sızmış bi̇r süper zekaydı!!
# 0
# boyle koklenmek isteyen varmi 19cm in karsinda yeni trasli 😉
# 1
# kadın fenomen oldu ama tersten 😁
# 1
# biz senin kürt olmanı dert etmiyorken=new version of ‘ben senin kürt olduğunu tahmin etmiştim aslında ama ayıp olur diye söylemedim’ ..
# 0
# ayrılalımmı diye şaka mı olur sen manyakmısın ibrahim tatlıses gibi beynime kurşun yiyip ölmedim resmen
# 0
# erkek demiyorum kesin oğlan eksik 😂
# 1
# tatil bok gibi gecerken birde okulları 6 gün yaptıklarını söylüyorlar vay
# 0
# birde şey var, ne giyseler yakişiyor ;) marka bir sey mesela  parayi sonradan kazananlar (parasi olan kirolar) uzerinde asla oyle durmuyor😂 kiyafet adam seçiyor. bu cemiyet başka bir şey karşiim 😋
# 1
# çekiyorum derken fotoğraf ablamında diyosun demi ?
# 1
# 62 den tavşan mı yoksa 69 dan..
# 1
# selam resimler tamamen bana ayit gec boşalan biriaiyim yurt disin dan turkiye geldim gecici sure burdayim sehir sorunum yok
# 1
# ne güzel söz katranı kaynatsan olurmu şeker cinsini .ktiğim cinsine çeker
# 1
# sen i̇ngiltelerde 19 ton altın rezervlerken benim insanım burada aç aç işsiz katıksız istifa et uzun etme #1dolar5liraerdoğani̇sti̇fa
# 1
# onlarca hristiyan, ıslam ve dinsiz ülkeler varken küçücük bir yahudi devletine tahammülsüzlük antisemitizmin disa vurumudur. ısrailin kendini savunmasi haktir. sakin insan haklari demeyin. ortadoğu devletlerini kiyasla ısrail yeterince demokratiktir.
# 0
# kadın dediğin balık gibi olacak, ne  öyle sikpek, pazu vb
# 0
# ırksız araform , gomünist - hümanist türk soycusu olmaktan iftihar ederim 🐺🇹🇷
# 0
# sigara ve alkole zerre saygım yok. bir insan bir şeyden en fazla ne kadar nefret edebilirse  kadar nefret ediyorum abartısız.
# 1
# negatif enerjilerinizi alıp hayatıma bay bay diyin
# 1
# sürekli kaybettim çünkü iyi kalpli içimdeki gerizekalı.
# 0
# bu ne la
# 1
# geriye kalan 0.68 lik katkı türkiye’mizin yüz karası hakemleri yüzünden olmuyor yoksa yüzde yüz başarı olacaktı.
# 1
# bence çin’in üzerine salınsın
# 0
# seküler kesimin kozmozdan elektron talep etmesi.
# 1
# chp önce başörtüsü konusunda kendi seçmen kitlesine rehabilitasyon hizmeti versin ne kadar reklam yaparsa yapsın çevremizde sağımızda solumuzda chp seçmeninin hala 30lu yıllarda takılı kaldığını görüyoruz zerre değişim yok
# 1
# ittifakın hedefi cumhur ittifakının 300'ün altında kalması. yoksa erdoğana karşı şanslarının olmadığını onlar da biliyor. amaç ülkeyi kısır döngüye sokmak. bunu sen de çok iyi biliyorsun.😎😎
# 1
# i̇srail işgal güçlerine ait uçaklar tarafından gazze'ye yine bir saldırı gerçekleştirildi. saldırıda filistinli aileye mensup biri bebek iki kişi şehit oldu, bir kişi yaralandı
# 0
# %70 taşeron mağdurları çok menun sizlerden
# 0
# hayatımda tanıdığım en yıkıcı insan sensin ve ben bundan nefret ettiğim halde kendimle başa çıkamıyorum
# 1
# ayak parmagini kapinin altina sikistir ve elindeki kahve de haliya dokulsun  an
# 0
# haklısın hocam senin de boşalmaman lazım. seni de tedavi edip kısırlaştıralım.
# 1
# i̇nşallah akşam yerden yere vururlar nefretimsin 6s
# 1
# emin misin? bence çok sinirli bir insansın bu soruma dahi tahammül edemeyip hemen hakaret edip rencide etmeye çalışıyorsun ve algılamada sorun yaşıyorsun ben senin masum olduğuna inanmıyorum kanıtım bu tavrın.
# 1
# ailen senden utanmışdır umarım bunu hissedebilen evlatlar yetiştirebildiysen tabi.
# 1
# #zonguldakescort tecrübelerin neden olduğu eğlenceleri inkar etmek olmaz. 📞 0977 398 98 46 📞
# 1
# ben paramparça olurken hiç bir şey yokmuş gibi davranan insanlarıb da mk
# 1
# anlık yukarıya bakıp yürüyordum kızın biride telefona bakarak yürüyordu kızla çarpmıştım aniden yavrucum sen burda napıyorsun bu saatte dedim kız salak dedi gitti. napıym ag boyu 1.50 civarı olunca ağzımdan kaçtı
# 0
# sen anlat karadeniz dizisinin şarkısı çok sinir bozucu değil mi sizce de?
# 1
# cehalet manzarayı kapatan ağaçlar gibidir ardında ne olduğunu bilirsin fakat bir adım yukarı çıkıp görmek istemezsin..#idamgelsin
# 1
# buda doğru zaten 1.5 milyonu olan adama ben acımam.ama aynısı senin başına gelse. yada farklı bir sektörde sen bir işe 1.5 milyon tl yatırmışın biri gelicek aynı işi 500 tl yapıcak kendine keriz gibi hissetmezmisin devlet sahip çıktı evetenseleri kalın devlettevatandaşı koruyor
# 0
# sussam gönül razı değil konuşsam tesiri yok. sagol ağzına sağlık🙏 cehennemin başköşesine konsun inşallah..
# 1
# siz anlatmaktan yorulursunuz onlar yemekten yorulmaz aksırıncaya tiksirincaya kadar yesinler burunlarindam gelsin.
# 1
# ona rağmen cb oyunuzu vereceksiniz sizde bi acayipsiniz
# 0
# 1..dırar gs fb maçında oynamayacaktı..2..fatih hoca akıllı adam bir sonraki bjk maçında hakemi etkiye aldı..mesaj haftayaydı..dırar bahane bjk maçı şahane adam kurt kurt 😂😂ondan  fatih terim siz kimsiniz ilk defa gördüm 🤣🤣
# 0
# çok şükür haram yemedik.. derken! 😂😂
# 1
# nere geliyon. ötür oturduğun yerde is var is.
# 0
# yoga: yoga, hindistan kaynaklı fiziksel ve zihinsel disiplinleri tarif etmek için kullanılan bir kelimedir. aynı zamanda hinduizm, budizm ve jainizm'de çeşitli meditatif uygulamalara da yoga adı verilmektedir. yani ineğe yapanların, putlara tapanların tapınma hareketleri.
# 1
# hopp gitti kafa!önceden suyu sütü bedava içiyodun dimi?ekrem başkan gelince paralı oldu!
# 1
# seni artık stalklamak değil bıçaklamak istiyorum yiğidim
# 1
# i̇zmit de oral ap olsa. mmmh
# 1
# kimde saklanacak sırasında varsa,kaybetmemek için makam sahibi yapıp,susturuluyor gibi..
# 1
# bla bla bla türbanlıyım bla bla bla bla bla bla bla bla türbanlıyım bla bla bla bla
# 1
# cirkinlesme seni baskanima sikayet ederim tartismali kongre istemiyoruz
# 1
# bu cacık șeyi de paylașıyosunuz ya yuhh diyorum artık!! listelenince 5 kișiye 0.2 eth vereceklermiș!! geçen de bu scam coinin telegram dedikodusu yayılıyodu :çok büyük haber yok exchange
# 1
# değilim ama sizler çok yakında pkk magduru olcaksınız kesin
# 0
# bak sen mağdura bak arkasını bi̇r yerlere dayamasa öyle kasıntılı kasıntılı konuşabi̇li̇rmi̇ çok geç kalınmış geeç
# 1
# hepsi birbirine benziyor lan dhdjkasmsj
# 1
# bence yıldırım tamam belki yemiş kasayıda doldurmuş olabilir ama çok çalıştı hizmet etti kasada dolu olunca vicdan yapar yemez. #i̇mamoğluçünkü hazırı yiyecek su süt vs ufak tefek şeyler yaparak yapılan büyük yatırımlardan malı götürecek cünkü kasa boş
# 1
# yengemlere ilgim var hepsi dolgun türbanlı istanbul anadolu yakası yeri olan aktifler mesaj atın konuşalım
# 0
# ben hiçbir ataya biat etmem. sizin gibi ölü sevici değilim.
# 1
# i̇nsaları eleştirirken bir dönüp bakın siz nesiniz diye.
# 1
# size içerde dısarda koyarak aldık  kupaları.son8 maçta 1 galibiyetiniz var yine koycaz merak etme
# 1
# i̇nsan olmak kuruş ile değil, duruş ile ölçülür. size yanlış öğretmişler
# 1
# fikirlerinizdeki karanlığı aydınlatabilmek için tüm ışığımızı kullanmaya çalışıyoruz 😉
# 1
# kendi varlıklarını ceaatlere borçlular,  yüzden olmamaları,olamayacakları mevkilerdeler.
# 1
# hem şuan diyanetin başındaki atatürk düşmanı ve boş yere türk milleti vergi veriyor bu şuan siyasi bir kuruma bağlı #diyanetkapatılsın
# 0
# .tayyip erdoğan,maltepe miting alanı 2.00.00 kişi alıyor demişti. sen şimdi cumhurbaşkanı .tayyip erdoğan’ yalancı(!) mı demek istiyorsun ?
# 0
# bekli̇yorum canım. buyur gel. bu kadar yüksekten uçtuğuna gör bulursun adresi̇. kuş bakışı gelmeni̇zi̇ dört gözle bekli̇yorum.
# 1
# ulan halbuki derginin adından anlamalıydık ya "sızıntı" adamlar sızmaya çalışıyormuş işte, biz de salakmışız gerçekten 😂
# 0
# hulusi akarda tersten sapladı özgür özel
# 1
# oktay vural foxta canlı yayındayken bombalandı. allah cezanızı versin. teorilerinizi bi kenara bırakın. itidalli olun allah rızası için.
# 1
# biz neyin derdindeyiz bunlar neyin peşinde.. onlarca insan ölmüş, evi yurdu harap olmuş bunlar #şiraz'ı rojhilat gösterme derdinde, #pjak' kampanya yaratma telaşında! #سیل
# 0
# sen söyledin de bu çerez kapaklara doymadi 😂😂 neyse ben essin olunca görecem onu
# 1
# kırışdar hiç böyle samimi değil
# 1
# #hampher’ın hatıratı. “konferanstan sonra şu karar alındı: her ne suretle olursa olsun #müslüman kuvvetlerini kırmak. bunun da en güzel yolu; aralarına nifak ve tefrika çıkarmak, i̇manlarını zayıflatmak için her şeye başvurmak.i̇manları ellerinden alınarak hristiyanlaştırılacaklar”
# 0
# haklısın sonuç belli başkan! sizler sistem üzerinde akpartinin oylarını aşırdınız.. neden hep binali yıldırımın oyları orn: 181 değil de 1 veya 0.. niye imamın oğlunun oyları hep doğru veya daha fazla.. az sabret bu yazdıklarınla kendine gol atma zamanın geliyor.
# 1
# negehan alçı işte etr’ın diploması diye ortalığa çıktı.. rte’nın diplomasını yayınlamak sanamı düştü.. rte diplomasını miting meydanlarında bir kez gösterse bütün dünya zaten haberdar olur..rte’nın diplomasını göstereceği mercii belli.. bunca yıl gırtlak patlatıldığında nerdeydin
# 0
# ulan  zaman 3 ay önce seçimde niye %70-80 oy verip seçtiler? fosile bak hele
# 1
# yau neden komik olmak için zorluyorsun kendini komik değilsin uzatma gari sus
# 1
# enderun usülü ne demek? teravih teravihtir. eğer amaç dikkat çekip birilerinin gözüne girmekse  ayrı.. di̇b olmak demek salih müslüman olmak demek olmadığını türk halkına öğrettiniz, sağolun.
# 1
# yok öyle bi şey sen uyduruyorsun bizden kimse hüküm giymedi bi tayfur havutcu var  da zaten fenerin kopegiymis
# 1
# şu anda partilerin içinde ve mecliste halkın belirlediği isimler yok ki zaten bütün partiler için diyorum bunu. bugün parti içinde veya mecliste görev almak istesen milyarlar ödemen gerekiyor. bugün her siyasi partinin içinde dost görünüp ülkeye düşman olanlar var.
# 1
# temmuz gelsin bari mq dünyası
# 0
#  kişi kendisi ve kendi gibi olduğunu bildiğimiz herkesi başa getirdi. allah kılıcını i̇mamoğlu ve chp ile vurdu. fakat halen gerek sosyal medyadan gerekse şirket de propagandaya devam ediyor. bunların hesabı sorulsun. ne kadar genel md. yard. varsa atılmalı.
# 1
# devlette çalışma gibi bir planım olmamasına rağmen mal gibi kpss'ye girecegim doğrudur.
# 1
# evet atarlandın birden çemkirdin unf falan yaptın atardır bu ama saçma yani görüşlerimizi bildirmek güzel tartışmakta fandoma dahil. ben senin görüşüne saygı duydum neyse konuşmamış sayalım🙋🏼‍♀️
# 1
# [ #ıvotebtsbbmas ] sevimli bir hesapsın fazla görmemiştim çünkü ben salak falanim neyse buraya girmeyelim ama cidden sevimli bir hesapsin seni sevdim beraber çocuklarımız için çokça çalışalım :')
# 0
# yükleyecek element olmadığındandır. 11 ile ilgisi yok yani. reset at geçer kirli kibirli dünyan sakinleşir
# 1
# elif az önce ıspanaklı gözlemenin içinde ıspanak oluyor dedi. bu kız böyle değildi naptiniz olum kıza?
# 1
# andropoz belirtisi.. sizde çok şey yapmayın arkadaşlar.. hadi burhan sende uzaklaş buralardan.
# 1
# kurtlar vadisi ilk 97 bölüm açık ara hayatımın ufku aw
# 1
# falcao için kap gelecek diye bir kişi ortaya bir şey atıyor ondan sonra galatasaray muhabirleri dahil onlarla beraber çakma duyumcular herkes atlıyor.
# 1
# akp'li kürt kızı niye kızlar daha çok inanıyor erdoğana hep merak etmişimdir
# 0
# hahaha çok esprilisiniz, acaba stadı yaparken drenaj durumunu metal yorgunluğu ile atlamış olabilir misiniz?
# 1
# senin tivitin işte neresi düzmece
# 0
# yeni bir şey alındığında, ya da yapıldığında hep sevinir ya insan. sanırım ilk defa yenisi yapıldı, eskisi kapatıldı diye sevinilmeyen, mutlu olunmayan tek şey. #ataturkhavalimani
# 1
# mahalle aile hısım akraba baskısı.bana sorduklarında hay ben sizin derdinizi mikeyim dememeye çalışıyorum çoğu kez.
# 1
# 5 yaşındaki komşumuzun çocuğu beni dövüşe davet etti ben de kabul etmeyince korkak tavuk korkak tavuk diye gaza getirmeye çalışıyor tam benlik laflar bunlar
# 0
#  kadar tembel bi milletiz ki okumuyoruz, öğrenmiyoruz, duyduklarımıza inanıyoruz ve en kötüsü de yanlış öğreniyoruz, aptal oluyoruz umarım bi şeyler değişir
# 1
# pardus dururken devlete milyon tane windows alınsın sonra da vatandaş iphone  boykot etsin. yer mi anadolu çocuğu? yer, ver gazi gitsin !!
# 0
# güzel bütün sanatçılar yazmaya başladılar biz sadece biz mi izledik diyoruz da eminim tüm türkiye seyretti  konuşmayı. hatta  bile seyretti. i̇çine dert olmuştur beter olsun.
# 1
# dereler ırmaklara, ırmaklar nehirlere, nehirler türklüğün ulu denizine doğru akmaya devam ediyor. yeis bize göre değil, kutlu olsun.
# 0
# ama ergen sözü sabıkalı bir söz .. bir yıldır  sözü gereksuz yete duymaktan kusacaz.. ama adam ne bilsin alakasız kişilerden aptal saptal tiplerden yediğimjz ayarları.
# 0
# amguard nedir yaa? ahahahahaha kral bu neçe tespittir yaa vur masaya da inlesin ortalık yargı dagıtmışsın tek kelime ile
# 0
# her otokraside olduğu gibi rus otokrasisinde de klasik yolsuzluk çarkı işlemiş ve bir bataklığa stad kurmuşlar. tabi stalingrad ın her yanı kutsal olunca başka yer bulamamışlardır.
# 0
# turkiyedeki en büyük cemaat kemalist cemaat. başta  olmak üzere hepsi kapatilmali. ıyi niyetle başlarlar sonu $$ la biter.
# 1
# yine hiçbir şey yapmadan oturduğum yerden şerefsiz oldum çok ilginç bi site
# 0
# bir gun oturup 2011 sezonu oncesi ve sonrasi gs'yi konusalim. kirden arindigi hic bir donem yok gsnin. bunu sabahlara kadar herkese anlatirim :)
# 1
# stros yopmoyo gorok yok diyonuz da stres yapılmıycak gibi değil ki, sisteme bak
# 1
# ağanın dediği gibi speğin ruhunu beyninden geçenleri bilmen lazım
# 0
# ya bi . gidin milletle kafa yapmayn 7 ocaktan beri hep geliyo bu adam çıkın olmıcak deyin herkes rahat etsin
# 1
# #crout yaa slk öyle desene xkdkdkdpmepxöwpdmxosmodempdf
# 1
# yapanı gebertmedikçe millet devlete saygı duymayacak i̇damı işte bu sebeple istiyoruz
# 1
# konser yada herhangi organizasyonlarınızda kesinlikle bu mi̇llet 15 temmuz ruhuna dahi̇l olmayan hi̇çbi̇r ki̇şi̇yi̇ sanatçıyı görmek i̇stemi̇yoruz.! bu devleti̇n başında i̇kti̇dar. ona uygun taraf kollayıp gözeti̇ceksi̇ni̇z.
# 1
# tek kelimeyle yanitladim yanlis neresinde bunun 😁😁 amiin
# 0
# tamam kardeşimde artık gına geldik her durumda hükümeti suçlutırlar ama ana ihanet çetesi chonin yaptığı hwr zarara gık diyemiyorlar hal böyle olunca tabii olarak bende eleştirmelerini denksiz ve algıya yönelik buluyorum ve canımı acıtıyor eleştirmek hakkımız ama hak ve haksızı🤨
# 0
# umudumu ülkeden  kadar çok kestimki yeniden seçim olmasını gram takmadım yani skkskskks kim gelirse gelsin artık bu ülke değiştirilemez, düzeltilemez. benim gözümde türkiye'nin muasır medeniyetler seviyesine ulaşması en az 100 yıl çünkü baştakiler değişse de bu ülkenin insanı +
# 1
# yiyin efendiler yiyin, bu han-ı iştiha sizin, doyunca, tıksırınca, çatlayıncaya kadar yiyin!
# 1
# bu ülkenin sorunu erdoğan dır tek adamlıgı bırakıp parlamenter sisteme acilen dönülmeli çok büyük hatakar yapıldı ne yazık halk bunu kriz ile hayat pahalıgı ile ödüyor birileri lüx hayat yaşıyor nedeni tepkisiz halk yıgını
# 0
# çok gülünce sevmiyom ya tebessümünün köpeğiyim  ayrı😬
# 1
# evlenince doğrudan akıl sağlığını mı kaybediyorsun bu ne ahahaha
# 1
# allah bana bir kardeş vermiş düşmana şükrettirir
# 1
# çiğ süt alacağıma akşam yemeğinde iki kaşık salmonella yerim en azından ne yediğimi bilirim
# 1
# fetöyüeleştirdik sizövdünüz sayın adnan oktar hocam fetöyü eleştiriyordu ama siz türkçe olimpiyatlarında övüyordunuz.
# 0
# türkiyede bi insana faşist veya ırkçı deniyosa çok büyük ihtimalle söyleyen kişi ırkçı veya faşisttir.
# 0
# reise kızgındım, bu sefer muhalefete oy vereyim dedim, muhalefette güzel başladı ama sonunda hepsi sapıttı, arkadaş yapılanları yıkacam, yok yapımı devam edenleri durdurucam. bu söylemler nedir arkadaş, kendi ayağınıza sıktınız resmen. yine çare reis.
# 0
# ...
# 0
# yine saçma sapan insanların sacma sapan hikayelerini dinleyerek günü bitirdim. 👾👾
# 1
# kuzuyu da yanında versin, bu ne ya
# 1
# makamda oturan şahıs  kadar millet şikayetçi, laf söylüyor dalga geçiyor bizimle 1500 arama var diyor.kadrolu elemanlarınızsa bunlar belayı bulmuşsunuz diyeyim.yok bizde böyle diyorsanız,biz belayı bulmuşuz.en iyisi sizinle çalışan firmalardan uzak duralım.
# 1
# #seçiminenkötüsloganı ekmek için ekmeleddin zirvede bıraktı bir başkasını aramaya gerek yok bence
# 1
# vekil olsaydı bunları söyleyebilecekmiydi.ikinci metin külünk vakası.
# 1
# 7 ölümcül hastalığa ek olarak öldürmeyen ama sürümsürüm süründüren süründürürken anlık geçiyor gibi olup aslında dalga geçerek nanik diyen lanet gibi bir şeysin sen migren.. düş yakamdan artık..
# 0
# müslümanlar iman kardeşidir. müslümandan diğer müslümana zarar gelmemelidir. müslüman müslümanın malını, canını, ırzını, namusunu  yokken de korur. #bunebiçimolay müslüman müslümana güvenemez hale geldi..
# 1
# ben çerkezköy deyim kendi evim var gelir misin peki
# 1
# trump seçildi diye bayram eden akpliler bu aralar ne düşünüyor acaba? demokrasi karşıtı siyaset en çok yapana zarar ama bunu anlamaları biraz zor oluyor. yaşasın demokrasi!
# 0
# bok gibi bir sabaha uyandım , aslında küfürler yazmam lazımdı ama ..
# 1
# devlet görevlileri işallah maşallah diye konuşmaz. görevini yapar yapmıyorsan bas istifanı sktir git.
# 1
# kediye köpeğe bir de el kadar bebeğe açılan instagram hesapları gerçekten mantık dışı 🤦🏻‍♀️ onların ağzından konuşur gibi yazmakta şizofren işi 🤣🤣 akıl fikir lütfen 🤡
# 0
#  buz zaten fenerin cagliari ile isla icin yaptigi anlasma, aman ne inovatif 🤣🤣
# 1
# kendi kendini bitirdiğin için teşekkür ederim.ben başka türlü vazgeçemezdim senden.
# 1
# 1407 çay kahve tost masaj vs vs gibi bir çok sözünü hala tutmayan bana bikaç seferdir görüldü atan pubg bağımlısı minik insan
# 0
# asgari ücret artışını da chp'nin seçim vaadinden çalmamışlar mıydı?
# 1
# keşke finansal köle kankim olsaydı..
# 0
# türk mitini organizesi ile bu patlamalar yapiliyordur. i̇şid türkiyenin taşeron örgütüdür. i̇stanbul secimleri icin milliyetcilik havasina ihtiyac duydular.
# 1
# bence bahçeli kankasıyla beraber asla kapısından geçmicem dediği sonrada avlusundan ayrılmadığı sarayda konusup, artık seçime gerek yok bütün işlere biz karar vercez uymayanıda içeri atıcaz diyebilir. artık hakimde biziz, mahkeme. seçende biziz seçilende hersey bizim diyebilir..
# 1
# önemli olan senin doğru söylediğin ınamayana boş yere çeneni yorma✋
# 0
# 'i̇şe soktuğum insanların duası beni cennete götürür' diyor. torpil yaparak hakkını çaldıklarının kul hakkını nedense aklına getirmiyor.
# 0
# sanıyorum ki bazıları insan olmaya karar verememiş daha,,
# 1
# aminakodumun istanbulu nefret ediyorum senden..çankırı ozur dilerim bitanem cok ozledim seni
# 1
# _perviz parvizabdullayev yalnızdeğildir
# 1
# siyasi partilerin derdi seçi̇m halkın derdi geçim oldu. meclis de halk ın yararına birşey konuşulmaz oldu hergün kavga kargaşa bakalım kim kazanacak
# 1
# kuvvacilar ne zaman devletçi oldular benim niye haberim olmadı
# 0
# içimde kıyametler koparken umrunda olmamasına rağmen umurundaymış gibi düşünüyorum belki de düşünmek istiyorumdur bilemiyorum ama bu sadece tekila ayarı moruk kips:(
# 0
# ağlasanız da zırlasanız da valla artık zalımın kızı olcam. hadi bakalım beni insanlara tanıttığınız gibi olma vakti 🔫
# 0
# 😂 sahil kentlerinde oturup akşama kadar vücudunu güneş kremleri ile koruyan beybi stratejik planlama yapıyor 😏 hadi güzelim savaş seni aşan şey ölen fakir fukara çocuğu olacak sende vatan sağolsun diyerek rant sağlayacaksın 😏 çok meraklı isen giy kefeni kendin git
# 1
# okul uzatmak da zor, mesela yarın 200’lilerin arasına gireceğim..
# 1
# emre ve olcaydan daha çok nefret ederiz
# 1
# şöyle bi arkaya bakıyorumda bulundugum yerden, herşey değişmiş ama sen aynısın aynı vasatlık aynı kalitesizlik aynı sahtekarlık
# 1
# sayın meydan cehalete laf anlatmayın anlamazlar
# 1
# bütün hırsız krallar; sömüren, haram yiyen bütün riyakar liderler, kişisel ikballerini ülke istikbalinden üstün tutan bütün yöneticiler, dış güçleri suçladı. bütün sorumsuz liderler, hak ve hukuk katili bütün zalim idareciler komplo sattı, muhalifleri ajanlık/hainlikle suçladı..
# 0
# şimdi ben denizi gördüm sizin sayenizde saolun allah razı olsun. ama canım suya girmek istedi giremedim uzaak. size de burda günah yazılırmi ?
# 1
# büyük başkan gereğini yapmış 👋👋 yeter artık boş beleş çalışmayıp maaş almaları..
# 1
# söyledikleri suç değil mi..? sn.cumhuriyet savcılarımız bu sözlerin hesabını sorar kendisinden..
# 1
# rt fatmaasaka: sıla vertigo heralde, ahmet kural’ın iddiasına göre 6-7 kere düşmüş, ahmet kural hiç dokunmadan bile düşüyor, 15 dakika sürdüyse kadın dakikada bir düşmüş, yazık kadının dengesi bozuk diye insan alır bir doktora falan götürür, ahmet kural’ı kınıyorum.
# 1
# doğru diyorsun biri görürse diye kourkuyolar
# 0
# bu kadar ağladığına göre enlemesine girmiş herhalde kral
# 1
# psikopat olduğumuzu yeni mi anlıyorsun ablacım ahahahahaha
# 0
# inanmıyorum abhi düşüne biliyor ben şok #gerçekler
# 1
# diyorum ki; aileleri bunların başını zorla başını örtmemiş. başörtü düşmanlığı ve itibarsızlaştırmak için özellikle giydirilmiş ve sosyal medyaya servis edilmiş. baktığım zaman bu oyunu da zevkle oynamışlar.bu bir tezgah. baştan sona tezgah. anıtkabir olayının başka versiyonu.
# 0
# şu *ktiğimin dünyasında herkesin vakti aşırı değerli. bir tek ben gün içerisinde on beş saat bile çalışsam değer verdiğim insanlara vakit ayırabiliyor onlar için fedakarlık yapabiliyorum. geriye kalan herkes aşırı yorgun ve zamansız.
# 1
# 2 cenabet maça gidiyorsunuz takıma güveniyorum ama sizin orada olmanızdan başka birşey endişelendirmiyor beni 😂😂
# 1
# şu hemcinslerimin kendini belli etmek için girdiği şekilleri görünce öğğhh diye kusasım geliyo
# 1
# lanet olsun böyle yobazlara lanet olsun  duşunduğunuz i̇badetler şeytan kilikli yaratıklar
# 0
# tabi tabi aniden gidiyo rastgele. hepside akpci. oruçlu aileler. koca masa varken yerde yerler ve sofra bezi değil masanın kendi örtüsünü yere sererler. şans işte. mukatterat.
# 1
# zaten başakşehir şerefsizi yine yenmiş
# 0
# arkadaş afganistan suriyelilerin ne işi var ülkemizde der durursunuz kardeşim bu kardeşlerimiz de olmasa sabah camide cemaat bulamıyoruz namaz kildiracak.. ne hale geldik nereye doğru gidiyoruz onlar ülkelerini terkedip geldiler ya sen içindeki namaz sevgisini nereye gonderdin😭
# 0
# sen ve sizin gibiler orada çukur açılsın iş makinaları yakılsın bunları isteyip sonra barış güvercini olursunuz,sonra işci emekci hakkı hikayesi
# 0
# ukalalık yapma diyor ve yanağına uyarı tokadını atıyor
# 1
# olum galiba siz hakketen burçlara inanıyorsunuz şaka yapmıyorsunuz
# 1
# valla adam gibi kutlama gorunce bile mutlu oluyo insan hiçbir yer de turuncu bayrak ampul falan yok hep kırmızı beyaz türk bayrağı😍
# 1
# meral akşener ismi tam bir şişirilmiş bir balondu. seçimlerde herkes bunu gördü. i̇yi̇ parti umarım meral’ kaybedenler kulübüne gönderir ve tarih sahnesinden siler.
# 1
# abi  içtiğinden sonra mı böyle oldun yoksa daha öncenden olmuşmuydun 😂😂
# 1
# yok, azize ve miran.. ben miran ile karşılaşmazlar miran reyyan'ı götürür dedim ama beraber fotoları var mk.
# 1
# bu yaptığın çok ayıp 😡 ne bileyim ben be
# 1
# i̇nşallah soyları tükenir kardeşim inşallah çok teşekkür ederim canımın içi
# 1
# kaç ayarsın güzelim ona göre bozalım?
# 1
# oğlu biraz hayırsız ya bilemedim
# 1
# başındaki örtüyü çıkarınca ‘ne kadar bilge bir insan oldun’ mu diyolar ne bu yarış.. hadi bakalm bu sayede ne çok bilgemiz olduğunu öğrendik.. başarı oranımız, bilinç katsayımız, kültür seviyemiz filan zirve olur diye bekliyorm artk.. şaptık şeker olduk oh mis..#10yearchallange
# 1
# bu ne ya bir kere dinle ya yeter yemin ederim kendimi parçalamak istiyorum kaldıramıyorum ben bunları
# 1
# ben üç gün çalışıyorum ama kalan dört günde de uyku tutmuyor madrid, her şeyin bedeli var kahretsin ki 😓🙃
# 0
# #alsancakescort #bucaescort #bornovaescort #karşıyakaescort #narlıdereescort 😍 alsancak 'ta kendi kendi evim de görüşüyorum sevgili tadın sevişiyorum sevişmeleri aceleye getirmiyorum hadi bitti mi demiyorum😘😘 ☎️03683558524☎️
# 1
# trabzon ne yaparsa yapsın eleştirilir , bazen rum olur bazen faşist bazen terörist , halbuki güzel insanlarız vatanını seven , ülkesine bağlı takımına bağlı . bu ülkede tek kural trabzon da herhangi bir kitle ne yaparsa yapsın komple trabzon' yik eleştir haritan sil :) komikler
# 0
# sizin dinde iftira atmak sevap galiba ?
# 1
# kızlar hiç güvenilecek yanınız yok
# 1
# i̇nsan sevdiği için tescilli manyak olabiliyorsa seviyordur bizi sınamayın
# 0
# şu güzel havada dershaneye gideceğim böyle adaletin taa..
# 1
# duygusuz değilim. sadece aynı şeye uzun süre üzülecek kadar salak değilim.
# 0
# #taksicileraçıklamabekliyor uberi yasaklayın yoksa taksiciler adam olmak, adam gibi hizmet etmek zorunda kalacaklar
# 1
# ohh 25 cm kalın büyük isteyenler
# 1
# yok yok kılıçdaroğlu açıkladı "sandıklarımızın güvenliğini sağladık kimse kaygılanmasın" diye yani artık boş yaygara yapamıyacaksınız
# 1
# metin akpınar:kadın sanyo diyemiyor, saniye diyor 🤫😂
# 1
# sen  alacası içinde fesatla hangi günü gün edicen.
# 0
# yazdığım gibi esarete boyun eğip iş bilmezlerin görevlendirilmesine müsaade ettiği için .cengiz suçlu ve #yönetimi̇stifa
# 1
# akrabası ölen üyemizle dalga geçmek mi? ah, tam da size yakışan bir mevzu. böyle devam edin, biz ne olursa olsun saygımızı koruyacağız ama siz her zaman gözümüzde egoist yaratıklar olarak kalacaksınız.
# 0
# eli iş tutmayan beylerimiz gelmiş burada boş yapıyor
# 1
# ayrıca mesihlik davasının bazı yahudiler tarafından ortaya atıldığını, kendisinin asla böyle bir iddiada bulunmadığına dair yemin üstüne yemin çeker, teminat üstüne teminat verir. dökmedik dil bırakmaz.
# 0
# eleştirelere kulak asmayın tüm taraftar dik duruş göstersin mavi̇ şi̇mşegi̇mi̇zi̇n arkasında olalım i̇tleri̇n mesajı ne adanademi̇rsporu yıpratır ne sayın başkanımız murat sancakı yıpratır mayısı bekleyeli̇m🙋‍♂️🙏🙏
# 1
# cnn’deki “seçim otobüsü” isimli programın adı “akp seçim otobüsü” olarak değiştirilmeli.
# 1
# hocam sizin abuk subuk haberleri twitlemenize hayranim.
# 1
# “ama bu projemiz için milli kıraathane vergisi alınacak” dese “hülooğğ” diye haykıracak bir topluluğa hitap ediyor, fazladan börek yemek işlerine bile gelir yani
# 1
# fizikten 70 aldım hangi mal tm'ci olduğumu söyledi yalaklanmasin
# 0
# bi ara volkancılar vardı sırf kargaşa cıkarmak için "vefa vefa" diye boş yapan insanlar
# 1
# dude 'moon bunu okuyan insanlar bilmeyecek mi senin lafı nereye çektiğini.. 'moon aptallara oynama biraz bana oyna yahuu:
# 0
# sizin için hak adalet bir anlam ifade etmiyor anlaşılan, araba kullanırken bile başkasının hakkını yersiniz..
# 1
# zaten bu röportaj neyin için? dizi 1 hafta önce sezon finali yaptı,4 ay yok. bu röportaj faydası ne? sadece külper prim içindir demek ki. gerçekten hiç gururun yok seni? #sakfandom senin torpili olduğunu öğrendi ama sen hala prim peşindesin #senanlatkaradeniz
# 1
# “kim, kendisine doğru yol apaçık belli olduktan sonra peygamber’ karşı çıkar, mü’minlerin yolundan başkasına uyarsa, biz, onu döndüğü yola çevirir ve (neticede) cehenneme sokarız. orası varılacak ne kötü bir yerdir.” (nisa, 4/115)
# 1
# #spormansettrt ekrandan seyirciye hakaret eden adam para kazanıyor trtde seviye çok düştü
# 1
# aslı doğan zaten zengin kızı. helal olsun. sonradan görmelere kapak olsun.kıskananlar çatlasın. mutlu aiile tablosu. 💐❤️ yarın çocukları olunca yediriip içireceği ekmek kapısına tabikii iyi bakacak. allah ömür boyu biir yastıkta kocaltsın. başınızda yıkayın ayaklarınızıda
# 1
# uzaktan iyi insanlarsınızdır eminim,  yüzden uzak durun
# 1
# #freeebruozkan i̇srail bizleri tutuklayarak kudüs yolundan alıkoyacağını düşünüyor bizler yıktığınızı yapmaya geliyoruz bizler ağlattıklarınızın göz yaşlarını silmeye geliyoruz bizler yetim bıraktıklarınızın başını okşamaya geliyoruz biz adaleti tecelli ettirmek için geliyor
# 0
# dedi duvarlar örmüşsün her bir tarafına, dedim ama bu duvar dediklerin hepsi ağaç, elma kokularına bak. benim yeşil bahçem, senin beton yüzün var. biraz yarıl da çiçek aç.
# 1
# ulan 17 senedir okumuş adamlara saya söve geldiniz, bu ne şimdi. en kral diplomalar ekmeleddin'de vardı, onu niye seçmedik?
# 0
# i̇ngiliz yine şaşırtmadı! boğaziçi oyununa dahil oldu i̇ngiltere merkezli medya kuruluşu bbc, boğaziçi üniversitesi'nde düzenlenen eylemler üzerinden ülke çapında protestolar düzenlenmesine üstü kapalı destek verdi.
# 1
# sen ekrem başkanı boş ver, son jeep  teslim ettin mi tc ankara büyük şehi̇r beledi̇yesi̇ne.. bitmişsin, tükenmişsin, partin bile seni adam yerine koymuyor. sen hala millete çamur atacağım diye uğraş..
# 0
# “fiyzi i̇ltin’ simimi bilmiyirim.” bu aralar akışıma en çok düşen boş beleş tweetlerden.  bi’ halta yaramayan çok bilmiş kardeşim, ’apalım yani oturduğun yerden beğenmiyorsan kadını? sırası mı,yeri mi? öyle veya böyle, günlerdir arkamızı kolluyorlar. ayıptır! #mazbatamiziverin
# 1
# gencecik bir akademisyenin katledilmesine hepimiz kahrolmuşken işi siyasete çevirip tüm ülkücülere ihale etmek adice bir fırsatçılık.
# 0
# siyaset- hazıra,  kadar çok yalan ve hile ve şeytanet içine girmiş ki, vesvese- şeyatîn hükmüne geçmiştir.. 📕sözler #bediüzzaman
# 0
# kendisini türk olarak göremiyenler de "varlığım türkiye varlığına armağan olsun. ne mutlu türkiye'liyim" desin. bunuda diyemeyenler bölücüdür.
# 1
# kendini toparla akitçi işiniz bitti çünkü keser dönüyor sap dönüyor bilesin akitçi
# 1
# parodi hesap göremiyorum, parodi şirket görüyorum. çözümsüzlük üstüne kurulmuş bir enkaz.
# 1
# sahura kalkıpta sabah namazını kılmayan da ne bilim biraz şeydir
# 1
# hakikati bulan baskalari farkli dusunuyor diye onu haykirmaktan cekiniyorsa budaladir
# 0
# kullandigim maskeyi yere atacak kadar davar yetistirilmedigim icin aileme tesekkur ederim
# 1
# bu ülkede ger ger gezinip "ben büyük ortadogu projesinin eşbaşkanıyım" diyordu. şimdi nerede siz biliyormusunuz? kimdi bu kişi? onu destekleyip gitmesini kim engelliyor?
# 0
# dünyanın en gelişmiş şehri canım yozgat’ım
# 1
# 😀 genel başkan kk ise il başkanı da böyle olur
# 1
# ühühü anasayfamda hiçbir şey yok exoyla olan bağlantım kesildi abv
# 1
# baba ben ne gördüm biliyo musun? birbirinin arkasından konuşup karşılıklı yalaklanmalarını gördüm😌
# 0
# ahirda ineklerle yasasinlar. zaten . bence gun gelicek bu karahmanin kafasina cok fena bi anne terligi gelicek ama nezaman. ama kesin gelicek biara demedi demeyin 🙄😋🤣🤨
# 1
# #alparslanhocamamesajım bu bir aşk meselesidir! zalimler anlayamaz.. yalakacılar anlayamaz.. satılmışlar anlayamaz.. dünya perestler anlayamaz..
# 0
# siz de kuraya idrar torbasından katılıyormuşsunuz doğru mu ?
# 1
# sinan engin çok büyük provakasyoncu helal olsun nasıl beşiktaş'ın işine gelecek senaryoları sayıyor tek tek olacakmiş gibi hepinizi üst üste koyacağız inşallah
# 0
# bazı degerli siyasetciler #vekilince dünya dönüyorsa iyilerin hatırına ama bilmem turkıye kimlerin hatırına yok olacak türkiye vatan bayrak candan politikacılar için var olur sayın i̇nce turkiyemiz için sizden başka kimseye güven kalmadı 2 yüzlü siyasetcilerden bıktık
# 0
# aile malı nerdeyse çoğu en azından açıklıyor sizin erdoğan da açıklasın da görelim sıkıyosa
# 1
# off ağır laf koydun üstad
# 1
# demin bahsettigim bey buydu max 4 puan bu burun her dik burna düsme kekologu👎🏻👎🏻
# 1
# anlatamadığınızı siz de biliyorsunuz. ama anladım. siz, karadawi’den içinde “islam devleti, fakirlik,savaşmak” ibareleri geçen bir ifadeyi paylaşınca ne yalan söyleyeyim heyecanlandım umutla selam olsun dedim. heyhat! şimdi  selamı geri alıyorum. ve
# 1
# bütün .ç ları bi araya toplanmış
# 1
# tahrifatci ahmet hoca, filistin ve kudüs davamiz diye de kitap yazmış. tahrifatseverler için kitapcilarda. kaçırmayın.
# 1
# aslında gerek inceyi tutanlar olsun,gerek kkoğlunu akp seçmeninden kafa yapısı olarak farkları yok çünkü tabloyu göremiyorlar
# 1
# gelecekse şimdiden diyete başlaması lazım son gördüğümde elkebir gibiydi
# 1
# 31-i̇şte yaşanan tüm bu sürecin sonucunda dağılan 2. cumhuriyetçiler ve destekçileri gidişlerini sosyal platformlar üzerinden gereksiz tutarsız söylemlerde bulunarak, geçtikleri yolları yıkıp yakarak dağılmaya devam ediyorlar.
# 1
# abd bizi bölmek istiyor. rusya bizi çok seviyor. alengirli iş çevirmemize de ses çıkartmıyor. hatta çanak tutuyor. yaşasın rusya.
# 0
# son takip ettiği 10 kişiden 8  kadınsa kaçın 10  da kadınsa koşarak uzaklaşın
# 1
